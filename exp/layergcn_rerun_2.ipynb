# %% [markdown]
# # LayerGCN Rerun 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/model_exp/LayerGCN
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/model_exp/LayerGCN

# %%
new_code = r'''
embedding_size: 128
# n_layers: [4]
n_layers : [4]
# reg_weight: [1e-02, 1e-03, 1e-04, 1e-05]
reg_weight: [1e-4]
dropout: [0.0]
hyper_parameters: ["n_layers", "dropout", "reg_weight"]
'''
with open("config.yaml", "w") as f:
    f.write(new_code)

# %% [markdown]
# **Yelp2018**

# %%
# !python main.py -m LayerGCN -d yelp2018
# Out:
# ██Server: 	747afdeb676f
# ██Dir: 	/content/drive/MyDrive/model_exp/LayerGCN
#
#
# gpu_id=0
# use_gpu=True
# seed=[2026]
# data_path=data/
# preprocessed_data=preprocessed_data/
# preprocessed_data_splitting=x_label
# load_preprocessed=False
# checkpoint_dir=saved
# save_recommended_topk=True
# recommend_topk=recommend_topk/
# embedding_size=128
# epochs=500
# train_batch_size=2048
# learner=adam
# learning_rate=0.001
# training_neg_sample_num=4
# use_neg_sampling=True
# use_full_sampling=False
# eval_step=1
# stopping_step=999
# min_user_inter_num=5
# min_item_inter_num=5
# max_user_inter_num=None
# max_item_inter_num=None
# USER_ID_FIELD=user_id:token
# ITEM_ID_FIELD=item_id:token
# load_cols=['user_id:token', 'item_id:token']
# field_separator=
# NEG_PREFIX=neg__
# split_ratio=[0.7, 0.1, 0.2]
# metrics=['Recall', 'NDCG', 'MAP', 'Precision']
# topk=[20]
# valid_metric=Recall@20
# eval_batch_size=4096
# hyper_parameters=['n_layers', 'dropout', 'reg_weight']
# dataset=yelp2018
# ...

# %% [markdown]
# **AmazonBook**

# %%
new_code = r'''
embedding_size: 64
# n_layers: [4]
n_layers : [4]
# reg_weight: [1e-02, 1e-03, 1e-04, 1e-05]
reg_weight: [1e-4]
dropout: [0.2] #Change dropout to for amazonbook
hyper_parameters: ["n_layers", "dropout", "reg_weight"]
'''
with open("configs/model/LayerGCN.yaml", "w") as f:
    f.write(new_code)

# %%
# !python main.py -m LayerGCN -d amazon-book
# Out:
# ██Server: 	5eb6f89cb6b1
# ██Dir: 	/content/drive/MyDrive/model_exp/LayerGCN
#
#
# gpu_id=0
# use_gpu=True
# seed=[2026]
# data_path=data/
# preprocessed_data=preprocessed_data/
# preprocessed_data_splitting=x_label
# load_preprocessed=False
# checkpoint_dir=saved
# save_recommended_topk=True
# recommend_topk=recommend_topk/
# embedding_size=64
# epochs=500
# train_batch_size=2048
# learner=adam
# learning_rate=0.001
# training_neg_sample_num=4
# use_neg_sampling=True
# use_full_sampling=False
# eval_step=1
# stopping_step=999
# min_user_inter_num=5
# min_item_inter_num=5
# max_user_inter_num=None
# max_item_inter_num=None
# USER_ID_FIELD=user_id:token
# ITEM_ID_FIELD=item_id:token
# load_cols=['user_id:token', 'item_id:token']
# field_separator=
# NEG_PREFIX=neg__
# split_ratio=[0.7, 0.1, 0.2]
# metrics=['Recall', 'NDCG', 'MAP', 'Precision']
# topk=[20]
# valid_metric=Recall@20
# eval_batch_size=4096
# hyper_parameters=['n_layers', 'dropout', 'reg_weight']
# dataset=amazon-book
# ...

# %% [markdown]
# **Gowalla**

# %%
# !python main.py -m LayerGCN -d gowalla
# Out:
# ██Server: 	cb8142651d13
# ██Dir: 	/content/drive/MyDrive/model_exp/LayerGCN
#
#
# gpu_id=0
# use_gpu=True
# seed=[2026]
# data_path=data/
# preprocessed_data=preprocessed_data/
# preprocessed_data_splitting=x_label
# load_preprocessed=False
# checkpoint_dir=saved
# save_recommended_topk=True
# recommend_topk=recommend_topk/
# embedding_size=128
# epochs=500
# train_batch_size=2048
# learner=adam
# learning_rate=0.001
# training_neg_sample_num=4
# use_neg_sampling=True
# use_full_sampling=False
# eval_step=1
# stopping_step=999
# min_user_inter_num=5
# min_item_inter_num=5
# max_user_inter_num=None
# max_item_inter_num=None
# USER_ID_FIELD=user_id:token
# ITEM_ID_FIELD=item_id:token
# load_cols=['user_id:token', 'item_id:token']
# field_separator=
# NEG_PREFIX=neg__
# split_ratio=[0.7, 0.1, 0.2]
# metrics=['Recall', 'NDCG', 'MAP', 'Precision']
# topk=[20]
# valid_metric=Recall@20
# eval_batch_size=4096
# hyper_parameters=['n_layers', 'dropout', 'reg_weight']
# dataset=gowalla
# ...

# %% [markdown]
# **MovieLen**

# %%
# !python main.py -m LayerGCN -d movielen

# %% [markdown]
# **GitStar**

# %%
# !python main.py -m LayerGCN -d gitstar
